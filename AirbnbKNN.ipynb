# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline

# %%
#Reading the CSV file airbnbAMS.csv which has 5646 rows
ams = pd.read_csv("airbnbAMS.csv",sep=";")
# As borough, overall satisfaction have NaN data I am dropping them.
ams = ams.drop('borough', 1)
ams = ams.drop('overall_satisfaction', 1)
ams = ams.drop('last_modified', 1)
ams.head()
# Out:
#    room_id  host_id     room_type                            neighborhood  \
# 0     2818     3159  Private room  Oostelijk Havengebied / Indische Buurt
# 1     6243     3813  Private room  Oostelijk Havengebied / Indische Buurt
# 2    15061    59297  Private room                              Westerpark
# 3    15865    59484  Private room                            Centrum Oost
# 4    20168    59484  Private room                            Centrum Oost
#
#    reviews  accommodates  bedrooms  price  minstay    latitude  longitude
# 0       77             2       1.0   90.0        3  52.365.755  4.941.419
# 1      116             4       1.0   75.0        2  52.379.212  4.926.324
# 2       53             4       1.0   66.0        2  52.382.685    487.613
# 3        1             4       1.0  151.0        3  52.363.786  4.893.392
# 4        4             2       1.0   90.0        3  52.365.087  4.893.541

# %%
#Removing the rows which do not have the data of the number of bedrooms
ams.dropna(subset =['bedrooms'], how='any', inplace = True) 
# Resetting index 
ams = ams.reset_index(drop=True)
#Removing the '.' in the latitude and longitude
ams.latitude = ams.latitude.str.replace(".", "")
ams.longitude = ams.longitude.str.replace(".", "")

ams
# Out:
#       room_id   host_id        room_type  \
# 0        2818      3159     Private room
# 1        6243      3813     Private room
# 2       15061     59297     Private room
# 3       15865     59484     Private room
# 4       20168     59484     Private room
# 5       20522     77484  Entire home/apt
# 6       22315  10378458  Entire home/apt
# 7       23651      9616     Private room
# 8       25488    106225  Entire home/apt
# 9       27573    119217     Private room
# 10      27886     97647  Entire home/apt
# 11      28658    123414     Private room
# 12      28871    124245     Private room
# 13      29051    124245     Private room
# 14      29217    125667     Private room
# 15      29346    126116  Entire home/apt
# 16      29554    127233  Entire home/apt
# 17      30431    131462  Entire home/apt
# 18      31080    133488  Entire home/apt
# 19      33127    143614  Entire home/apt
# 20      34357    148238  Entire home/apt
# 21      38266    164204  Entire home/apt
# 22      39688    170462  Entire home/apt
# 23      41075    178227  Entire home/apt
# 24      41091    178294  Entire home/apt
# 25      41125    178515  Entire home/apt
# 26      42161    184354  Entire home/apt
# 27      42987      3813     Private room
# 28      43006    187716  Entire home/apt
# 29      43054    187861     Private room
# ...       ...       ...              ...
# 5584  3101135  15767347  Entire home/apt
# 5585  3103488  15777283     Private room
# 5586  3103960   4948127     Private room
# 5587  3104186   8890345     Private room
# 5588  3104501   4704138  Entire home/apt
# 5589  3107606   6463493     Private room
# 5590  3107750   8778234  Entire home/apt
# 5591  3107901   2965482  Entire home/apt
# 5592  3107999  15799839  Entire home/apt
# 5593  3108119  15800137  Entire home/apt
# 5594  3108495   2965482  Entire home/apt
# 5595  3108519   5535682  Entire home/apt
# 5596  3108546  15777283  Entire home/apt
# 5597  3108695  15802044     Private room
# 5598  3108734  15208324  Entire home/apt
# 5599  3109281  12769834  Entire home/apt
# 5600  3109476   1606566  Entire home/apt
# 5601  3109892   5305276  Entire home/apt
# 5602  3110145   2965482     Private room
# 5603  3110401  12180919     Private room
# 5604  3110414  14431527     Private room
# 5605  3110941   6127483     Private room
# 5606  3112496  15659562  Entire home/apt
# 5607  3113368  15424013  Entire home/apt
# 5608  3113629  15820762     Private room
# 5609  3113738   8449480  Entire home/apt
# 5610  3113878  15822709  Entire home/apt
# 5611  3114271  13986430  Entire home/apt
# 5612  3114851  15827316  Entire home/apt
# 5613  3115135  15828426     Private room
#
#                                 neighborhood  reviews  accommodates  bedrooms  \
# 0     Oostelijk Havengebied / Indische Buurt       77             2       1.0
# 1     Oostelijk Havengebied / Indische Buurt      116             4       1.0
# 2                                 Westerpark       53             4       1.0
# 3                               Centrum Oost        1             4       1.0
# 4                               Centrum Oost        4             2       1.0
# 5                    De Pijp / Rivierenbuurt      139             2       1.0
# 6                                   Oud Oost        6             6       2.0
# 7                    De Pijp / Rivierenbuurt       36             3       1.0
# 8     Oostelijk Havengebied / Indische Buurt       46             6       3.0
# 9                               Centrum Oost       53             2       1.0
# 10                              Centrum West        4             2       1.0
# 11                    De Baarsjes / Oud West      161             4       1.0
# 12                              Centrum Oost        1             2       1.0
# 13                              Centrum Oost       58             1       1.0
# 14                 Noord-West / Noord-Midden      110             4       1.0
# 15                 Noord-West / Noord-Midden        3             2       3.0
# 16                              Centrum West       41             2       1.0
# 17                              Centrum Oost        3             2       1.0
# 18                 Noord-West / Noord-Midden        7             4       3.0
# 19                               Slotervaart        2             3       1.0
# 20                                Westerpark        3             4       3.0
# 21                              Centrum West      141             3       1.0
# 22                             Bos en Lommer        8             4       2.0
# 23                             Bos en Lommer       19             4       2.0
# 24                   Ijburg / Eiland Zeeburg       11             5       2.0
# 25                              Centrum West       45             2       1.0
# 26                           Watergraafsmeer        3             2       1.0
# 27    Oostelijk Havengebied / Indische Buurt       36             2       1.0
# 28                                  Oud Oost       11             2       1.0
# 29                           Watergraafsmeer       11             2       1.0
# ...                                      ...      ...           ...       ...
# 5584               Noord-West / Noord-Midden        0             4       2.0
# 5585  Oostelijk Havengebied / Indische Buurt        0             2       1.0
# 5586                 Ijburg / Eiland Zeeburg        0             2       1.0
# 5587                                Oud Oost        0             2       1.0
# 5588                             Slotervaart        0             5       4.0
# 5589                  De Baarsjes / Oud West        0             2       1.0
# 5590                            Centrum Oost        0             2       0.0
# 5591                  De Baarsjes / Oud West        0             6       2.0
# 5592                            Centrum West        0             2       1.0
# 5593               Noord-West / Noord-Midden        0             4       1.0
# 5594                  De Baarsjes / Oud West        0             4       1.0
# 5595                 De Pijp / Rivierenbuurt        0             2       0.0
# 5596  Oostelijk Havengebied / Indische Buurt        0             4       2.0
# 5597                              Westerpark        0             1       1.0
# 5598                  De Aker / Nieuw Sloten        0             3       2.0
# 5599               Noord-West / Noord-Midden        0             2       1.0
# 5600                           Bos en Lommer        0             2       1.0
# 5601                           Bos en Lommer        0             2       1.0
# 5602                  De Baarsjes / Oud West        0             4       1.0
# 5603  Oostelijk Havengebied / Indische Buurt        0             2       1.0
columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
# doing a 0.7/0.3 split
X_train, X_test, y_train, y_test = train_test_split( X, ams['price'], test_size=0.3, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (3929, 5) (3929,)
# Test set: (1685, 5) (1685,)

# %%
k = 6
#Train Model and Predict  
neigh = KNeighborsClassifier(n_neighbors = k).fit(X_train,y_train)
#neigh

#PREDICT
yhat = neigh.predict(X_test)


from sklearn import metrics
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))

Ks = 100
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))
ConfustionMx = [];
for n in range(1,Ks):
    
    #Train Model and Predict  
    neigh = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    yhat=neigh.predict(X_test)
    mean_acc[n-1] = metrics.accuracy_score(y_test, yhat)

    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])

mean_acc
# Out:
# Train set Accuracy:  0.191397302112
# Test set Accuracy:  0.0356083086053
# array([ 0.03560831,  0.03382789,  0.03204748,  0.03086053,  0.03679525,
#         0.03560831,  0.0379822 ,  0.04391691,  0.04510386,  0.0504451 ,
#         0.0504451 ,  0.04985163,  0.04688427,  0.04747774,  0.04747774,
#         0.05400593,  0.05459941,  0.05637982,  0.05697329,  0.05519288,
#         0.05578635,  0.05637982,  0.05875371,  0.05994065,  0.05934718,
#         0.05934718,  0.06350148,  0.05756677,  0.05994065,  0.06409496,
#         0.06290801,  0.06409496,  0.06231454,  0.06053412,  0.06290801,
#         0.06350148,  0.06409496,  0.06290801,  0.06350148,  0.05875371,
#         0.05816024,  0.05934718,  0.06231454,  0.06409496,  0.05816024,
#         0.06290801,  0.06172107,  0.06350148,  0.06409496,  0.06468843,
#         0.06587537,  0.06646884,  0.06765579,  0.06706231,  0.06765579,
#         0.06587537,  0.06884273,  0.07121662,  0.07002967,  0.07240356,
#         0.07299703,  0.07121662,  0.07121662,  0.07418398,  0.07774481,
#         0.07121662,  0.07121662,  0.0694362 ,  0.0735905 ,  0.07240356,
#         0.0735905 ,  0.07181009,  0.07121662,  0.06824926,  0.06409496,
#         0.06231454,  0.0652819 ,  0.06587537,  0.06646884,  0.06587537,
#         0.06290801,  0.06468843,  0.06409496,  0.06409496,  0.06172107,
#         0.0652819 ,  0.06409496,  0.0652819 ,  0.06587537,  0.06290801,
#         0.06587537,  0.06587537,  0.06706231,  0.06587537,  0.0652819 ,
#         0.0694362 ,  0.06706231,  0.07002967,  0.0694362 ])

# %%
#Plotting to check the various accuracies at different k
plt.plot(range(1,Ks),mean_acc,'g')
plt.fill_between(range(1,Ks),mean_acc - 1 * std_acc,mean_acc + 1 * std_acc, alpha=0.10)
plt.legend(('Accuracy ', '+/- 3xstd'))
plt.ylabel('Accuracy ')
plt.xlabel('Number of Nabors (K)')
plt.tight_layout()
plt.show()

# %%
print( "The best accuracy was ", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was  0.0777448071217 with k= 65

# %%
from sklearn.metrics import f1_score
f1_score(y_test, yhat, average='weighted')
# Out:
# /Users/shuklap/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1113: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/shuklap/anaconda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1115: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# 0.049674745299619391

# %%
from sklearn.metrics import jaccard_similarity_score
jaccard_similarity_score(y_test, yhat)
# Out:
# 0.06943620178041543

# %%
k = 65

neigh = KNeighborsClassifier(n_neighbors = 65).fit(X_train,y_train)
#neigh

#PREDICT THE PRICE ON THE TEST CASE
yhat = neigh.predict(X_test)

# %%
yhat
# Out:
# array([ 151.,  115.,  229., ...,  153.,   84.,  115.])
